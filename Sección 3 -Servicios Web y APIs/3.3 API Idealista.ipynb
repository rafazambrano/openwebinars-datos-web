# %%
import json
import requests
from requests.auth import HTTPBasicAuth

idealista_url = "https://api.idealista.com/oauth/token"
r = requests.post(idealista_url,
                  auth=HTTPBasicAuth("9imfkl9ugl3ofiv9b95i7am1w98yzpu7", "8nZfatljCytZ"),
                  data={"grant_type": "client_credentials"})
print(r.text)
token_response = json.loads(r.text)
token_value = token_response["access_token"]
print("Token: " + token_value)

country = 'es'
center = '40.42938099999995,-3.7097526269835726'
numPage = '1'
distance = '1000'
propertyType = 'homes'
operation = 'rent'

api_url = "http://api.idealista.com/3.5/es/search?center="+center+"&country="+country+"&distance="+distance+"&propertyType="+propertyType+"&operation="+operation
print(api_url)

headers = {"Authorization": "Bearer " + token_value}
r = requests.post(api_url, headers=headers)
#print(r.text)
search_json = r.text
search_response = json.loads(search_json)
search_pretty = json.dumps(search_response, indent=4, sort_keys=True)
print(search_pretty)
# Out:
# {"access_token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU2MDc2NDEwMSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiZDBhNzAwNWEtY2U0YS00Y2MwLWFjMDAtYjEzMTY3NDg3NWVlIiwiY2xpZW50X2lkIjoiOWltZmtsOXVnbDNvZml2OWI5NWk3YW0xdzk4eXpwdTcifQ.p9k9G3bscolHCtYIiwc7XEN_zQs4N6L_b1daUmyTs_8","token_type":"bearer","expires_in":43200,"scope":"read","jti":"d0a7005a-ce4a-4cc0-ac00-b131674875ee"}
# Token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzY29wZSI6WyJyZWFkIl0sImV4cCI6MTU2MDc2NDEwMSwiYXV0aG9yaXRpZXMiOlsiUk9MRV9QVUJMSUMiXSwianRpIjoiZDBhNzAwNWEtY2U0YS00Y2MwLWFjMDAtYjEzMTY3NDg3NWVlIiwiY2xpZW50X2lkIjoiOWltZmtsOXVnbDNvZml2OWI5NWk3YW0xdzk4eXpwdTcifQ.p9k9G3bscolHCtYIiwc7XEN_zQs4N6L_b1daUmyTs_8
# http://api.idealista.com/3.5/es/search?center=40.42938099999995,-3.7097526269835726&country=es&distance=1000&propertyType=homes&operation=rent
# {
#     "actualPage": 1,
#     "elementList": [
#         {
#             "address": "Calle de Bravo Murillo",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "813",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "floor": "3",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4344519,
#             "longitude": -3.7028246,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 13,
#             "operation": "rent",
#             "parkingSpace": {
#                 "hasParkingSpace": true,
#                 "isParkingSpaceIncludedInPrice": true
#             },
#             "price": 750.0,
#             "priceByArea": 10.0,
#             "propertyCode": "25122058",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 75.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso en Calle de Bravo Murillo"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/27/b2/42/678644379.jpg",
#             "url": "https://www.idealista.com/inmueble/25122058/"
#         },
#         {
#             "address": "Calle Ventura Rodr\u00edguez",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "524",
#             "district": "Moncloa",
#             "exterior": true,
#             "externalReference": "GN-VENTUrarodriguez1280",
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": true,
#             "latitude": 40.4266806,
#             "longitude": -3.7148275,
#             "municipality": "Madrid",
#             "neighborhood": "Arg\u00fcelles",
#             "newDevelopment": false,
#             "numPhotos": 63,
#             "operation": "rent",
#             "parkingSpace": {
#                 "hasParkingSpace": true,
#                 "isParkingSpaceIncludedInPrice": false,
#                 "parkingSpacePrice": 140.0
#             },
#             "price": 1280.0,
#             "priceByArea": 14.0,
#             "propertyCode": "85896806",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 93.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arg\u00fcelles, Madrid",
#                 "title": "Piso en Calle Ventura Rodr\u00edguez"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/f4/4e/53/678239793.jpg",
#             "url": "https://www.idealista.com/inmueble/85896806/"
#         },
#         {
#             "address": "Calle Alberto Aguilera",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "658",
#             "district": "Chamber\u00ed",
#             "exterior": false,
#             "externalReference": "ALQ-13120",
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4306037,
#             "longitude": -3.7173613,
#             "municipality": "Madrid",
#             "neighborhood": "Gaztambide",
#             "newDevelopment": false,
#             "numPhotos": 30,
#             "operation": "rent",
#             "price": 1350.0,
#             "priceByArea": 14.0,
#             "propertyCode": "26939926",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 100.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Gaztambide, Madrid",
#                 "title": "Piso en Calle Alberto Aguilera"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/95/a9/b1/675195473.jpg",
#             "url": "https://www.idealista.com/inmueble/26939926/"
#         },
#         {
#             "address": "Calle de la Princesa",
#             "bathrooms": 3,
#             "country": "es",
#             "detailedType": {
#                 "subTypology": "penthouse",
#                 "typology": "flat"
#             },
#             "distance": "533",
#             "district": "Moncloa",
#             "exterior": true,
#             "floor": "8",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": true,
#             "hasVideo": false,
#             "latitude": 40.4295521,
#             "longitude": -3.7160543,
#             "municipality": "Madrid",
#             "neighborhood": "Arg\u00fcelles",
#             "newDevelopment": false,
#             "numPhotos": 43,
#             "operation": "rent",
#             "parkingSpace": {
#                 "hasParkingSpace": true,
#                 "isParkingSpaceIncludedInPrice": false,
#                 "parkingSpacePrice": 150.0
#             },
#             "price": 4500.0,
#             "priceByArea": 20.0,
#             "propertyCode": "85212816",
#             "propertyType": "penthouse",
#             "province": "Madrid",
#             "rooms": 3,
#             "showAddress": false,
#             "size": 230.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arg\u00fcelles, Madrid",
#                 "title": "\u00c1tico en Calle de la Princesa"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e1/62/6d/657111767.jpg",
#             "url": "https://www.idealista.com/inmueble/85212816/"
#         },
#         {
#             "address": "Calle Pez, 7",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "801",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "A-151",
#             "floor": "4",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": true,
#             "hasVideo": false,
#             "latitude": 40.4232446,
#             "longitude": -3.7047904,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 25,
#             "operation": "rent",
#             "price": 1150.0,
#             "priceByArea": 23.0,
#             "propertyCode": "28303964",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": true,
#             "size": 50.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Piso en Calle Pez, 7"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/a7/c4/57/68113031.jpg",
#             "url": "https://www.idealista.com/inmueble/28303964/"
#         },
#         {
#             "address": "Calle Juan \u00c1lvarez Mendiz\u00e1bal",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "697",
#             "district": "Moncloa",
#             "exterior": true,
#             "externalReference": "236",
#             "floor": "3",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4247299,
#             "longitude": -3.7152814,
#             "municipality": "Madrid",
#             "neighborhood": "Arg\u00fcelles",
#             "newDevelopment": false,
#             "numPhotos": 15,
#             "operation": "rent",
#             "price": 1500.0,
#             "priceByArea": 20.0,
#             "propertyCode": "85836190",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 75.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arg\u00fcelles, Madrid",
#                 "title": "Piso en Calle Juan \u00c1lvarez Mendiz\u00e1bal"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/3f/5e/00/676544830.jpg",
#             "url": "https://www.idealista.com/inmueble/85836190/"
#         },
#         {
#             "address": "Calle Churruca",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "subTypology": "studio",
#                 "typology": "flat"
#             },
#             "distance": "749",
#             "district": "Centro",
#             "exterior": true,
#             "floor": "3",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4278742,
#             "longitude": -3.7011202,
#             "municipality": "Madrid",
#             "neighborhood": "Chueca-Justicia",
#             "newDevelopment": false,
#             "numPhotos": 20,
#             "operation": "rent",
#             "price": 850.0,
#             "priceByArea": 23.0,
#             "propertyCode": "85894685",
#             "propertyType": "studio",
#             "province": "Madrid",
#             "rooms": 0,
#             "showAddress": false,
#             "size": 37.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Chueca-Justicia, Madrid",
#                 "title": "Estudio en Calle Churruca"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/de/11/fa/678252102.jpg",
#             "url": "https://www.idealista.com/inmueble/85894685/"
#         },
#         {
#             "address": "Calle de San Bernardo, Madrid",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "917",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "00698",
#             "floor": "4",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4212855,
#             "longitude": -3.7076588,
#             "municipality": "Madrid",
#             "neighborhood": "Palacio",
#             "newDevelopment": false,
#             "numPhotos": 19,
#             "operation": "rent",
#             "price": 1600.0,
#             "priceByArea": 21.0,
#             "propertyCode": "82934866",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 77.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Palacio, Madrid",
#                 "title": "Piso en Calle de San Bernardo, Madrid"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/3c/54/d8/607898750.jpg",
#             "url": "https://www.idealista.com/inmueble/82934866/"
#         },
#         {
#             "address": "Calle Fuencarral",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "766",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "floor": "3",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": true,
#             "hasVideo": false,
#             "latitude": 40.4313229,
#             "longitude": -3.7010665,
#             "municipality": "Madrid",
#             "neighborhood": "Trafalgar",
#             "newDevelopment": false,
#             "numPhotos": 23,
#             "operation": "rent",
#             "price": 1400.0,
#             "priceByArea": 21.0,
#             "propertyCode": "85845928",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": false,
#             "size": 67.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Trafalgar, Madrid",
#                 "title": "Piso en Calle Fuencarral"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e7/d0/98/676840447.jpg",
#             "url": "https://www.idealista.com/inmueble/85845928/"
#         },
#         {
#             "address": "Calle de Mart\u00edn de los Heros",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "subTypology": "penthouse",
#                 "typology": "flat"
#             },
#             "distance": "707",
#             "district": "Moncloa",
#             "exterior": true,
#             "floor": "5",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4240097,
#             "longitude": -3.7142301,
#             "municipality": "Madrid",
#             "neighborhood": "Arg\u00fcelles",
#             "newDevelopment": false,
#             "numPhotos": 19,
#             "operation": "rent",
#             "price": 1450.0,
#             "priceByArea": 29.0,
#             "propertyCode": "85845643",
#             "propertyType": "penthouse",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": false,
#             "size": 50.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arg\u00fcelles, Madrid",
#                 "title": "\u00c1tico en Calle de Mart\u00edn de los Heros"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/17/7e/7e/676835947.jpg",
#             "url": "https://www.idealista.com/inmueble/85845643/"
#         },
#         {
#             "address": "Calle de Jordan s/n",
#             "bathrooms": 2,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "725",
#             "district": "Chamber\u00ed",
#             "exterior": false,
#             "floor": "bj",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4329844,
#             "longitude": -3.7026122,
#             "municipality": "Madrid",
#             "neighborhood": "Trafalgar",
#             "newDevelopment": false,
#             "numPhotos": 17,
#             "operation": "rent",
#             "price": 2200.0,
#             "priceByArea": 18.0,
#             "propertyCode": "85904955",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 4,
#             "showAddress": true,
#             "size": 125.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Trafalgar, Madrid",
#                 "title": "Piso en Calle de Jordan s/n"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e7/94/cd/678460495.jpg",
#             "url": "https://www.idealista.com/inmueble/85904955/"
#         },
#         {
#             "address": "Calle tutor, 59",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "841",
#             "district": "Moncloa",
#             "exterior": false,
#             "floor": "2",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": false,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4321381,
#             "longitude": -3.7190114,
#             "municipality": "Madrid",
#             "neighborhood": "Arg\u00fcelles",
#             "newDevelopment": false,
#             "numPhotos": 14,
#             "operation": "rent",
#             "price": 850.0,
#             "priceByArea": 19.0,
#             "propertyCode": "34191035",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": true,
#             "size": 45.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arg\u00fcelles, Madrid",
#                 "title": "Piso en Calle tutor, 59"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/ef/34/0c/160111921.jpg",
#             "url": "https://www.idealista.com/inmueble/34191035/"
#         },
#         {
#             "address": "Calle Donoso Cort\u00e9s, 80",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "901",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.436502,
#             "longitude": -3.7148399,
#             "municipality": "Madrid",
#             "neighborhood": "Gaztambide",
#             "newDevelopment": false,
#             "numPhotos": 18,
#             "operation": "rent",
#             "price": 900.0,
#             "priceByArea": 20.0,
#             "propertyCode": "1790515",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": true,
#             "size": 45.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Gaztambide, Madrid",
#                 "title": "Piso en Calle Donoso Cort\u00e9s, 80"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/90/id.pro.es.image.master/dd/70/76/678637560.jpg",
#             "url": "https://www.idealista.com/inmueble/1790515/"
#         },
#         {
#             "address": "pez, 19",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "subTypology": "studio",
#                 "typology": "flat"
#             },
#             "distance": "696",
#             "district": "Centro",
#             "exterior": true,
#             "externalReference": "p19",
#             "floor": "5",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4238695,
#             "longitude": -3.7058351,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 19,
#             "operation": "rent",
#             "price": 650.0,
#             "priceByArea": 26.0,
#             "propertyCode": "33996547",
#             "propertyType": "studio",
#             "province": "Madrid",
#             "rooms": 0,
#             "showAddress": true,
#             "size": 25.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Estudio en pez, 19"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/b3/3a/f8/156186193.jpg",
#             "url": "https://www.idealista.com/inmueble/33996547/"
#         },
#         {
#             "address": "Calle Escosura, 8",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "644",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4347234,
#             "longitude": -3.7067835,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 15,
#             "operation": "rent",
#             "price": 1250.0,
#             "priceByArea": 21.0,
#             "propertyCode": "81421011",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": true,
#             "size": 60.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso en Calle Escosura, 8"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/65/76/e0/678628675.jpg",
#             "url": "https://www.idealista.com/inmueble/81421011/"
#         },
#         {
#             "address": "Fernando el Cat\u00f3lico, 48",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "605",
#             "district": "Chamber\u00ed",
#             "exterior": false,
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.434403,
#             "longitude": -3.712534,
#             "municipality": "Madrid",
#             "neighborhood": "Gaztambide",
#             "newDevelopment": false,
#             "numPhotos": 28,
#             "operation": "rent",
#             "price": 1100.0,
#             "priceByArea": 26.0,
#             "propertyCode": "85909481",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": true,
#             "size": 42.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Gaztambide, Madrid",
#                 "title": "Piso en Fernando el Cat\u00f3lico, 48"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/ae/84/e9/678623059.jpg",
#             "url": "https://www.idealista.com/inmueble/85909481/"
#         },
#         {
#             "address": "Calle de Rodr\u00edguez San Pedro, 23",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "270",
#             "district": "Chamber\u00ed",
#             "exterior": false,
#             "floor": "2",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4315873,
#             "longitude": -3.7111066,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 7,
#             "operation": "rent",
#             "price": 1300.0,
#             "priceByArea": 20.0,
#             "propertyCode": "85909358",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 3,
#             "showAddress": true,
#             "size": 65.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso en Calle de Rodr\u00edguez San Pedro, 23"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/e2/5b/87/678614932.jpg",
#             "url": "https://www.idealista.com/inmueble/85909358/"
#         },
#         {
#             "address": "Calle de Galileo, Madrid, 57",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "709",
#             "district": "Chamber\u00ed",
#             "exterior": false,
#             "floor": "2",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4357437,
#             "longitude": -3.7103929,
#             "municipality": "Madrid",
#             "neighborhood": "Arapiles",
#             "newDevelopment": false,
#             "numPhotos": 16,
#             "operation": "rent",
#             "price": 1550.0,
#             "priceByArea": 28.0,
#             "propertyCode": "82144200",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 1,
#             "showAddress": true,
#             "size": 55.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Arapiles, Madrid",
#                 "title": "Piso en Calle de Galileo, Madrid, 57"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/1f/eb/38/592984730.jpg",
#             "url": "https://www.idealista.com/inmueble/82144200/"
#         },
#         {
#             "address": "Plaza Dos de Mayo",
#             "bathrooms": 1,
#             "country": "es",
#             "detailedType": {
#                 "typology": "flat"
#             },
#             "distance": "645",
#             "district": "Centro",
#             "exterior": true,
#             "floor": "1",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4252605,
#             "longitude": -3.7043848,
#             "municipality": "Madrid",
#             "neighborhood": "Malasa\u00f1a-Universidad",
#             "newDevelopment": false,
#             "numPhotos": 26,
#             "operation": "rent",
#             "price": 1700.0,
#             "priceByArea": 20.0,
#             "propertyCode": "85909247",
#             "propertyType": "flat",
#             "province": "Madrid",
#             "rooms": 2,
#             "showAddress": false,
#             "size": 87.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Malasa\u00f1a-Universidad, Madrid",
#                 "title": "Piso en Plaza Dos de Mayo"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/68/51/1c/678609080.jpg",
#             "url": "https://www.idealista.com/inmueble/85909247/"
#         },
#         {
#             "address": "Calle Jos\u00e9 Mara\u00f1\u00f3n",
#             "bathrooms": 2,
#             "country": "es",
#             "detailedType": {
#                 "subTypology": "penthouse",
#                 "typology": "flat"
#             },
#             "distance": "928",
#             "district": "Chamber\u00ed",
#             "exterior": true,
#             "floor": "6",
#             "has360": false,
#             "has3DTour": false,
#             "hasLift": true,
#             "hasPlan": false,
#             "hasVideo": false,
#             "latitude": 40.4306152,
#             "longitude": -3.6989,
#             "municipality": "Madrid",
#             "neighborhood": "Trafalgar",
#             "newDevelopment": false,
#             "numPhotos": 21,
#             "operation": "rent",
#             "price": 1700.0,
#             "priceByArea": 14.0,
#             "propertyCode": "85909124",
#             "propertyType": "penthouse",
#             "province": "Madrid",
#             "rooms": 3,
#             "showAddress": false,
#             "size": 120.0,
#             "status": "good",
#             "suggestedTexts": {
#                 "subtitle": "Trafalgar, Madrid",
#                 "title": "\u00c1tico en Calle Jos\u00e9 Mara\u00f1\u00f3n"
#             },
#             "thumbnail": "https://img3.idealista.com/blur/WEB_LISTING/0/id.pro.es.image.master/c3/ba/08/678601953.jpg",
#             "url": "https://www.idealista.com/inmueble/85909124/"
#         }
#     ],
#     "hiddenResults": false,
#     "itemsPerPage": 20,
#     "lowerRangePosition": 0,
#     "numPaginations": 0,
#     "paginable": true,
#     "summary": [
#         "Alquilar",
#         "Viviendas",
#         "barrio Malasa\u00f1a-Universidad, Madrid",
#         "Todos los precios",
#         "Todos los tama\u00f1os"
#     ],
#     "total": 1467,
#     "totalPages": 74,
#     "upperRangePosition": 20
# }
